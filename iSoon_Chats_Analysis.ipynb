# %% [markdown]
# ## Exploring iSOON's Leaked Chats
#
# Ref: [I-SOON Leak News](https://www.darkreading.com/threat-intelligence/-isoon-contractor-helps-the-prc-hack-foreign-governments-companies)

# %% [markdown]
# ### Setup Dependencies

# %%
import sys
import os
import nltk
from wordcloud import WordCloud,STOPWORDS
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from matplotlib import rcParams
import spacy
import gensim
from gensim.parsing.preprocessing import STOPWORDS as gensim_stopwords
from gensim.parsing.preprocessing import remove_stopwords
from pprint import pprint

# %% [markdown]
# ## Process Unstructured Text
#
# Remove unnecessary stopwords from the given text input.

# %% [markdown]
# ### Read Chat File

# %%
INPUT_FILE_PATH = "leaked_docs/isoon_chats_english.txt"

# %%
path = os.path.join(os.getcwd(),INPUT_FILE_PATH)
with open(path,"r") as fh:
        file_data = fh.read()

# %% [markdown]
# ### Load Stopwords

# %%
stopwords_list = []
spacy_en_model = spacy.load('en_core_web_sm')
nltk.download("stopwords")

spacy_stopwords = list(spacy_en_model.Defaults.stop_words)
nltk_stopwords = stopwords.words("english")
gensim_stopwords = list(gensim_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to /home/bikram-
# [nltk_data]     xps/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopwords_list.extend(spacy_stopwords + nltk_stopwords + gensim_stopwords)
stopwords_list.extend([
    'td',
    'tr',
    'NULL'
])

# %%
# Remove stopwords from given text
file_data = remove_stopwords(file_data)

# %% [markdown]
# ## Generate Wordcloud

# %%
MAX_WORDS_IN_WORDCLOUD = 500
WORDCLOUD_BACKGROUND_COLOR = "black"

# %%
#call the wordcloud Constructor 
WC = WordCloud(
    stopwords=stopwords_list,
    max_words=MAX_WORDS_IN_WORDCLOUD,
    background_color=WORDCLOUD_BACKGROUND_COLOR, 
    width=1800, 
    height=800, 
    collocations=False).generate(file_data)

# %%
plt.figure(figsize=(25,15), facecolor='white')
plt.imshow(WC)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Extract Interesting Strings

# %% [markdown]
# ### Extract observables/selectors with `ioc-finder`

# %%
from ioc_finder import find_iocs

ALLOWED_IOC_TYPES = [
    # "asns",
    # "attack_mitigations",
    # "attack_tactics",
    # "attack_techniques",
    # "authentihashes",
    "bitcoin_addresses",
    # "cves",
    "domains",
    "email_addresses",
    # "email_addresses_complete",
    # "file_paths",
    # "google_adsense_publisher_ids",
    # "google_analytics_tracker_ids",
    # "imphashes",
    # "ipv4_cidrs",
    "ipv4s",
    # "ipv6s",
    # "mac_addresses",
    "md5s",
    "monero_addresses",
    # "registry_key_paths",
    "sha1s",
    "sha256s",
    # "sha512s",
    # "ssdeeps",
    # "tlp_labels",
    "urls",
    "user_agents",
    "xmpp_addresses",
]

# %%
# observables = parse_domain_names(file_data)
observables = find_iocs(file_data, included_ioc_types=ALLOWED_IOC_TYPES)

# %%
# Cleanup domains - remove all .md files
observables['domains'] = [domain for domain in observables['domains'] if not domain.endswith('-en.md')]

# %%
# Save extracted strings to disk
import json

EXTRACTED_STRINGS_OUTPUT_FILE = 'data_output/interesting_strings.json'
with open(EXTRACTED_STRINGS_OUTPUT_FILE, 'w') as wfile:
    json.dump(observables, wfile)

# %%
pprint(observables)
# Out:
# {'bitcoin_addresses': [],
#  'domains': ['meeting.tencent.com',
#              'www.w66369.com',
#              'gd9189.com',
#              'baike.baidu.com',
#              't.wss.ink',
#              'm.sohu.com',
#              'www.cyberdefensemagazine.com',
#              'w81518.com',
#              'zhuanlan.zhihu.com',
#              'finance.sina.com.cn',
#              'www.yutainews.com',
#              'surl.amap.com',
#              'translate.google.com',
#              'm.guancha.cn',
#              'www.cac.gov.cn',
#              'pan.baidu.com',
#              'www.plap.cn',
#              'mjj-rocrpy.vaiwan.com',
#              'selectarticlenewsbyid.do',
#              'www.57w66.com',
#              'drdo.gov.in',
#              'mahagst.gov.in',
#              'www.w81519.com',
#              'w66588.com',
#              'qq.com'],
#  'email_addresses': ['576514445@qq.com'],
#  'ipv4s': ['74.120.172.10', '8.218.67.52', '121.37.141.219'],
#  'md5s': ['b2c05c44c5204a04bbe4e86791fda307'],
#  'monero_addresses': [],
#  'sha1s': [],
#  'sha256s': [],
#  'urls': ['https://www.plap.cn/index/selectArticleNewsById.do?id=B2C05C44C5204A04BBE4E86791FDA307',
#           'https://74.120.172.10:10092/home',
#           'https://translate.google.com/translate?hl=en&sl=auto&tl=en&u=https://meeting.tencent.com/s/4zEAlh2Uoc6x',
#           'http://www.yutainews.com/gzgq/2020/0805/16079.html',
#           'https://pan.baidu.com/s/1EykC-iTf6iMj_DoGY1aM9A',
#           'https://www.w66369.com/',
#           'https://finance.sina.com.cn/stock/stockzmt/2020-07-29/doc-iivhvpwx8123040.shtml',
#           'https://www.cyberdefensemagazine.com/top-100-cybersecurity-hackers/',
#           'https://baike.baidu.com/item/%E8%82%96%E6%9C%88%E5%BC%BA/20449509',
#           'https://pan.baidu.com/s/1OngMYY5nldSdgxL5yyFcaQ',
#           'http://mjj-rocrpy.vaiwan.com/srrjvc',
#           'https://www.w81519.com/',
#           'https://translate.google.com/translate?hl=en&sl=auto&tl=en&u=https://gd9189.com/deposit',
#           'https://zhuanlan.zhihu.com/p/435968069',
#           'https://surl.amap.com/9cMhnYJt0nf',
#           'https://www.57w66.com/',
#           'https://t.wss.ink/f/89rr3wno4i5',
#           'https://m.guancha.cn/XiangGangTianQi',
#           'https://m.sohu.com/a/444553365_652525'],
#  'user_agents': [],
#  'xmpp_addresses': []}

# %% [markdown]
# ### Extract Entities via Named Entity Extraction (NER)

# %%
from spacy import displacy
from collections import Counter
import en_core_web_sm

nlp = en_core_web_sm.load()

# %%
SPACY_TEXT_LENGTH_LIMIT = 1000000

doc = nlp(file_data[:SPACY_TEXT_LENGTH_LIMIT])
extracted_entities = list(set([(X.text, X.label_) for X in doc.ents]))

# %% [markdown]
# #### Output All Entities as a DataFrame

# %%
import pandas as pd

df = pd.DataFrame.from_records(extracted_entities, columns = ['entity_name', 'entity_type'])

# %%
# Save DF to CSV
DF_OUTPUT_FILE = 'data_output/ner_entities.csv'
df.to_csv(DF_OUTPUT_FILE)

# %% [markdown]
# #### List Top Mentioned Locations, Nationalities, Organizations and Individuals
#
# Ref: https://stackoverflow.com/questions/70835924/how-to-get-a-description-for-each-spacy-ner-entity

# %%
NUMBER_OF_RECORDS_LIMIT = 20

def get_most_common_entites(entity_type):
    extracted_entities = [(X.text, X.label_) for X in doc.ents if X.label_ == entity_type]
    result = Counter(extracted_entities).most_common(NUMBER_OF_RECORDS_LIMIT)
    pprint(result)

# %%
MOST_COMMON_ENTITY_TYPES = [
    'GPE', 
    'PERSON', 
    'NORP', 
    'ORG', 
    'PRODUCT', 
    'MONEY', 
    'LOC', 
    'FAC',
    'LAW',
]

for entity_type in MOST_COMMON_ENTITY_TYPES:
    print(f'Top observed {spacy.explain(entity_type)} ({entity_type}):')
    print('---------------------------------------------')
    get_most_common_entites(entity_type)
    print()
# Out:
# Top observed Countries, cities, states (GPE):
# ---------------------------------------------
# [(('Chengdu', 'GPE'), 86),
#  (('Jiangsu', 'GPE'), 83),
#  (('’s', 'GPE'), 75),
#  (('Wangchai', 'GPE'), 65),
#  (('Hainan', 'GPE'), 54),
#  (('gzp1991101', 'GPE'), 53),
#  (('Shanghai', 'GPE'), 51),
#  (('China', 'GPE'), 44),
#  (('Sichuan', 'GPE'), 39),
#  (('Shaanxi', 'GPE'), 37),
#  (('Xinjiang', 'GPE'), 35),
#  (('Nanjing', 'GPE'), 34),
#  (('Yancheng', 'GPE'), 30),
#  (('n’t', 'GPE'), 23),
#  (('Beijing', 'GPE'), 20),
#  (('Xiaoliang', 'GPE'), 19),
#  (('Chongqing', 'GPE'), 15),
#  (('Yunnan', 'GPE'), 15),
#  (('Hong Kong', 'GPE'), 14),
#  (('Wuxi', 'GPE'), 14)]
#
# Top observed People, including fictional (PERSON):
# ---------------------------------------------
# [(('qq78263462', 'PERSON'), 337),
#  (('just910420', 'PERSON'), 163),
#  (('Qi Anxin', 'PERSON'), 59),
#  (('C', 'PERSON'), 59),
#  (('lengmo', 'PERSON'), 53),
#  (('Wu', 'PERSON'), 48),
#  (('Wang Zhe', 'PERSON'), 46),
#  (('Dong', 'PERSON'), 44),
#  (('Xu Qian', 'PERSON'), 41),
#  (('Zhou Weiwei', 'PERSON'), 37),
#  (('Wang', 'PERSON'), 34),
#  (('just910420 lengmo', 'PERSON'), 29),
#  (('Zhao Hengyu', 'PERSON'), 26),
#  (('Gong', 'PERSON'), 21),
#  (('SWEET5683yao', 'PERSON'), 21),
#  (('An Xun', 'PERSON'), 20),
#  (('Huang Le', 'PERSON'), 20),
#  (('Dali', 'PERSON'), 20),
#  (('Anxun', 'PERSON'), 19),
#  (('Hmm', 'PERSON'), 19)]
#
# Top observed Nationalities or religious or political groups (NORP):
# ---------------------------------------------
# [(('hack05112', 'NORP'), 50),
#  (('’s', 'NORP'), 19),
#  (('Chinese', 'NORP'), 10),
#  (('Hui', 'NORP'), 9),
#  (('Sichuan', 'NORP'), 7),
#  (('Han', 'NORP'), 4),
#  (('European', 'NORP'), 4),
#  (('Vietnamese', 'NORP'), 3),
#  (('Indian', 'NORP'), 3),
#  (('PP', 'NORP'), 3),
#  (('Xiaojuan', 'NORP'), 3),
#  (('Korean', 'NORP'), 2),
#  (('Philippine', 'NORP'), 2),
#  (('South Korean', 'NORP'), 2),
#  (('Scan', 'NORP'), 2),
#  (('Alibaba', 'NORP'), 2),
#  (('Suqian', 'NORP'), 2),
#  (('Buddhist', 'NORP'), 2),
#  (('A+', 'NORP'), 2),
#  (('Thai', 'NORP'), 2)]
#
# Top observed Companies, agencies, institutions, etc. (ORG):
# ---------------------------------------------
# [(('wxid_zb45i0rc71yk21', 'ORG'), 610),
#  (('TZ', 'ORG'), 41),
#  (('gzp1991101 wxid_7p054rmzkhqf21', 'ORG'), 34),
#  (('wxid_nv9bv435fz3722 wxid_70w3p1jin84k22', 'ORG'), 31),
#  (('Anxun College', 'ORG'), 24),
#  (('WeChat', 'ORG'), 22),
#  (('ken73224', 'ORG'), 22),
#  (('NATO', 'ORG'), 18),
#  (('adpw90 好 adpw90', 'ORG'), 14),
#  (('TB', 'ORG'), 13),
#  (('Android', 'ORG'), 10),
#  (('wxid_zb45i0rc71yk21 wxid_zb45i0rc71yk21', 'ORG'), 9),
#  (('gzp1991101', 'ORG'), 9),
#  (('Vietnam Academy Social Sciences', 'ORG'), 8),
#  (('wxid_5390224027312 wxid_70w3p1jin84k22', 'ORG'), 8),
#  (('TW', 'ORG'), 8),
#  (('IP', 'ORG'), 7),
#  (('The Sichuan Department', 'ORG'), 6),
#  (('Needed', 'ORG'), 5),
#  (('Boss C', 'ORG'), 5)]
#
# Top observed Objects, vehicles, foods, etc. (not services) (PRODUCT):
# ---------------------------------------------
# [(('Viagra', 'PRODUCT'), 14),
#  (('？', 'PRODUCT'), 9),
#  (('Cao', 'PRODUCT'), 3),
#  (('？ lengmo Shutd0wn', 'PRODUCT'), 3),
#  (('Juniper', 'PRODUCT'), 2),
#  (('SRX110H2', 'PRODUCT'), 2),
#  (('Cancel', 'PRODUCT'), 2),
#  (('Strengthen', 'PRODUCT'), 2),
#  (('CRM DingTalk', 'PRODUCT'), 2),
#  (('Hold fist][Hold fist][Hold', 'PRODUCT'), 1),
#  (('G7', 'PRODUCT'), 1),
#  (('Understood', 'PRODUCT'), 1),
#  (('Password wxid_zb45i0rc71yk21', 'PRODUCT'), 1),
#  (('Tgen-B4', 'PRODUCT'), 1),
#  (('？ wxid_70w3p1jin84k22', 'PRODUCT'), 1),
#  (('wxid_nv9bv435fz3722 Told', 'PRODUCT'), 1),
#  (('Yuanyuan', 'PRODUCT'), 1),
#  (('goods···Haha', 'PRODUCT'), 1),
#  (('Cao Rui', 'PRODUCT'), 1),
#  (('Malay', 'PRODUCT'), 1)]
#
# Top observed Monetary values, including unit (MONEY):
# ---------------------------------------------
# [(('2,000 yuan', 'MONEY'), 3),
#  (('20,000 yuan', 'MONEY'), 2),
#  (('thousand yuan', 'MONEY'), 2),
#  (('200 million yuan', 'MONEY'), 2),
#  (('40,000 yuan', 'MONEY'), 2),
#  (('500 yuan', 'MONEY'), 2),
#  (('10,000 yuan', 'MONEY'), 2),
#  (('n’t penny', 'MONEY'), 2),
#  (('100,000 yuan', 'MONEY'), 2),
#  (("394c-4576-b373-7c53f1abbd94_0.png'", 'MONEY'), 1),
#  (('4.50,000 yuan', 'MONEY'), 1),
#  (('million wxid_12n748um1thl21', 'MONEY'), 1),
#  (('360 yuan', 'MONEY'), 1),
#  (('1 billion year', 'MONEY'), 1),
#  (('20,000 30,000 yuan', 'MONEY'), 1),
#  (('tens millions yuan', 'MONEY'), 1),
#  (('1.188 million yuan', 'MONEY'), 1),
#  (('tens thousands yuan', 'MONEY'), 1),
#  (('16.5 billion', 'MONEY'), 1),
#  (('6.3 million yuan', 'MONEY'), 1)]
#
# Top observed Non-GPE locations, mountain ranges, bodies of water (LOC):
# ---------------------------------------------
# [(('East China', 'LOC'), 16),
#  (('Kexun', 'LOC'), 5),
#  (('Inner Mongolia', 'LOC'), 4),
#  (('Southwest', 'LOC'), 2),
#  (('，，，， Shutd0wn', 'LOC'), 2),
#  (('Hahahaha', 'LOC'), 2),
#  (('Southeast Asia', 'LOC'), 2),
#  (('Europe', 'LOC'), 2),
#  (('Northeast', 'LOC'), 2),
#  (('Northeast China', 'LOC'), 2),
#  (('Jinjiang District', 'LOC'), 1),
#  (('Fengtai District', 'LOC'), 1),
#  (('Shutd0wn Notification', 'LOC'), 1),
#  (('Put holiday', 'LOC'), 1),
#  (('Chengdu East Railway Station', 'LOC'), 1),
#  (('East Station', 'LOC'), 1),
#  (('west east lengmo', 'LOC'), 1),
#  (('Western Huanhua', 'LOC'), 1),
#  (('Send', 'LOC'), 1),
#  (('+ Shutd0wn', 'LOC'), 1)]
#
# Top observed Buildings, airports, highways, bridges, etc. (FAC):
# ---------------------------------------------
# [(('Didn’t', 'FAC'), 3),
#  (('Can’t', 'FAC'), 3),
#  (('Awesome', 'FAC'), 2),
#  (('Shaanxi Lhasa', 'FAC'), 2),
#  (('Sichuan Hall', 'FAC'), 2),
#  (('Disneyland', 'FAC'), 2),
#  (('Awesome wxid_zb45i0rc71yk21', 'FAC'), 1),
#  (('Shuangtie Plaza', 'FAC'), 1),
#  (('The Great Wall', 'FAC'), 1),
#  (('Jiangxi Legend Supreme', 'FAC'), 1),
#  (('Going Nanjing Shutd0wn', 'FAC'), 1),
#  (('Headache', 'FAC'), 1),
#  (('08:30:56', 'FAC'), 1),
#  (('Send Shanghai Nanjing Shutd0wn', 'FAC'), 1),
#  (('Didi', 'FAC'), 1),
#  (('Building 76', 'FAC'), 1),
#  (('n’t matter.</tr><tr>2020-11-06', 'FAC'), 1),
#  (('Crowne Plaza', 'FAC'), 1),
#  (('Qingyun Tower', 'FAC'), 1),
#  (('Xinjiang Shaanxi', 'FAC'), 1)]
#
# Top observed Named documents made into laws. (LAW):
# ---------------------------------------------
# [(('Pwn 4道', 'LAW'), 1),
#  (('Sun 1 Shutd0wn', 'LAW'), 1),
#  (('The Everbright Convention Exhibition', 'LAW'), 1),
#  (('that</', 'LAW'), 1),
#  (('adpw90 1 adpw90', 'LAW'), 1)]
